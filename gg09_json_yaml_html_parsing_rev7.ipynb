# %% [markdown]
# # Web Scraping using API
# - When you type www.google.com in your browser's address bar, your computer is actually asking the www.google.com server for a web page; the server returns the page to your browser.
# - APIs work much the same way, except instead of your web browser asking for a web page, your program asks for data. The API usually returns this data in JavaScript Object Notation (JSON) format.
#   - GET request: to retrieve information from the OpenNotify API.
#   -

# %% [markdown]
# ### Crawling and Scraping
# - Crawling refers to the process of automatically traversing through a website and following links to other pages in order to discover and index content.
# - Scraping, on the other hand, refers to the process of extracting specific data elements from web pages. Scraping involves sending HTTP requests to web pages and then parsing the HTML or other markup language in the response to extract the desired data.
# - Crawling focuses on discovering and indexing web pages, while scraping targets specific data extraction from those pages

# %% [markdown]
# # JSON format
# - json: JavaScript Object Notation (자바 스크립트 객체 표기법)
# - 데이터를 쉽게 '교환' 하고 '저장' 하기 위한 텍스트 기반의 데이터 교환 표준

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import json
from bs4 import BeautifulSoup

# %%
# exercise 1 : a simple json format
obj = """
{
    "name": "Kim",
    "places_lived": ["Seoul", "Korea"],
    "pet": null,
    "siblings": [{"name": "Scott", "age":25, "pet":"Zuko"}]
}
"""

# %%
type(obj)
# Out:
# str

# %%
r = json.loads(obj)   # decoding (json --> dict)
print(r)
type(r)
# Out:
# {'name': 'Kim', 'places_lived': ['Seoul', 'Korea'], 'pet': None, 'siblings': [{'name': 'Scott', 'age': 25, 'pet': 'Zuko'}]}
# dict

# %%
json.dumps(r)    # encoding (dict --> json)
# Out:
# '{"name": "Kim", "places_lived": ["Seoul", "Korea"], "pet": null, "siblings": [{"name": "Scott", "age": 25, "pet": "Zuko"}]}'

# %%
# Exercise 2 (from https://rfriend.tistory.com/474)
py_data = {

    "1.FirstName": "Gildong",
    "2.LastName": "Hong",
    "3.Age": 20,
    "4.University": "Hangook University",
    "5.Courses": [
        {
            "Classes": [
                "Probability",
                "Generalized Linear Model",
                "Categorical Data Analysis"
            ],
            "Major": "Statistics"
        },
        {
            "Classes": [
                "Data Structure",
                "Programming",
                "Algorithms"
            ],
            "Minor": "ComputerScience"
        }
    ]
}

# %%
type(py_data)
# Out:
# dict

# %%
py_data.keys()
# py_data.items()
# Out:
# dict_keys(['1.FirstName', '2.LastName', '3.Age', '4.University', '5.Courses'])

# %%
py_data.values()
# Out:
# dict_values(['Gildong', 'Hong', 20, 'Hangook University', [{'Classes': ['Probability', 'Generalized Linear Model', 'Categorical Data Analysis'], 'Major': 'Statistics'}, {'Classes': ['Data Structure', 'Programming', 'Algorithms'], 'Minor': 'ComputerScience'}]])

# %%
py_data['5.Courses']
# Out:
# [{'Classes': ['Probability',
#    'Generalized Linear Model',
#    'Categorical Data Analysis'],
#   'Major': 'Statistics'},
#  {'Classes': ['Data Structure', 'Programming', 'Algorithms'],
#   'Minor': 'ComputerScience'}]

# %%
import json
json_str = json.dumps(py_data)
print(json_str)
type(json_str)
# Out:
# {"1.FirstName": "Gildong", "2.LastName": "Hong", "3.Age": 20, "4.University": "Hangook University", "5.Courses": [{"Classes": ["Probability", "Generalized Linear Model", "Categorical Data Analysis"], "Major": "Statistics"}, {"Classes": ["Data Structure", "Programming", "Algorithms"], "Minor": "ComputerScience"}]}
# str

# %%
pd.Series(py_data)
# Out:
# 1.FirstName                                               Gildong
# 2.LastName                                                   Hong
# 3.Age                                                          20
# 4.University                                   Hangook University
# 5.Courses       [{'Classes': ['Probability', 'Generalized Line...
# dtype: object

# %%
pd.DataFrame(py_data)
# Out:
#   1.FirstName 2.LastName  3.Age        4.University  \
# 0     Gildong       Hong     20  Hangook University
# 1     Gildong       Hong     20  Hangook University
#
#                                            5.Courses
# 0  {'Classes': ['Probability', 'Generalized Linea...
# 1  {'Classes': ['Data Structure', 'Programming', ...

# %%
pd.DataFrame(py_data).iloc[:,-1]
# Out:
# 0    {'Classes': ['Probability', 'Generalized Linea...
# 1    {'Classes': ['Data Structure', 'Programming', ...
# Name: 5.Courses, dtype: object

# %%
pd.DataFrame.from_dict(py_data)
# Out:
#   1.FirstName 2.LastName  3.Age        4.University  \
# 0     Gildong       Hong     20  Hangook University
# 1     Gildong       Hong     20  Hangook University
#
#                                            5.Courses
# 0  {'Classes': ['Probability', 'Generalized Linea...
# 1  {'Classes': ['Data Structure', 'Programming', ...

# %%
pd.json_normalize(py_data)
# Out:
#   1.FirstName 2.LastName  3.Age        4.University  \
# 0     Gildong       Hong     20  Hangook University
#
#                                            5.Courses
# 0  [{'Classes': ['Probability', 'Generalized Line...

# %%
py_data['5.Courses']
# Out:
# [{'Classes': ['Probability',
#    'Generalized Linear Model',
#    'Categorical Data Analysis'],
#   'Major': 'Statistics'},
#  {'Classes': ['Data Structure', 'Programming', 'Algorithms'],
#   'Minor': 'ComputerScience'}]

# %%
pd.json_normalize(py_data, "5.Courses")
# Out:
#                                              Classes       Major  \
# 0  [Probability, Generalized Linear Model, Catego...  Statistics
# 1          [Data Structure, Programming, Algorithms]         NaN
#
#              Minor
# 0              NaN
# 1  ComputerScience

# %%
pd.json_normalize(py_data, "5.Courses", ['3.Age'])
# Out:
#                                              Classes       Major  \
# 0  [Probability, Generalized Linear Model, Catego...  Statistics
# 1          [Data Structure, Programming, Algorithms]         NaN
#
#              Minor 3.Age
# 0              NaN    20
# 1  ComputerScience    20

# %% [markdown]
# # json_normalize (data, record_path, meta, ...)
# - data: dict or list of dict
# - record_path : decode 해줘야할 열 지정 [{}, {}, {} ....]
# - meta : decode 하는 열과 동일 차원에 존재하는 열들 중 데이터 프레임에 포함시킬 열 선택

# %%
# JSON exercise3
# from https://pandas.pydata.org/pandas-docs/stable/reference/api/\
#              pandas.io.json.json_normalize.html
data = [{'state': 'Florida',
         'shortname': 'FL',
         'info': {'governor': 'Rick Scott'},
         'counties': [{'name': 'Dade', 'population': 12345},
                      {'name': 'Broward', 'population': 40000},
                      {'name': 'Palm Beach', 'population': 60000}]},
        {'state': 'Ohio',
         'shortname': 'OH',
         'info': {'governor': 'John Kasich'},
         'counties': [{'name': 'Summit', 'population': 1234},
                      {'name': 'Cuyahoga', 'population': 1337}]}]

# %%
type(data), len(data)
# Out:
# (list, 2)

# %%
pd.json_normalize(data)
# Out:
#      state shortname                                           counties  \
# 0  Florida        FL  [{'name': 'Dade', 'population': 12345}, {'name...
# 1     Ohio        OH  [{'name': 'Summit', 'population': 1234}, {'nam...
#
#   info.governor
# 0    Rick Scott
# 1   John Kasich

# %%
pd.json_normalize(data, 'counties')
# Out:
#          name  population
# 0        Dade       12345
# 1     Broward       40000
# 2  Palm Beach       60000
# 3      Summit        1234
# 4    Cuyahoga        1337

# %%
pd.json_normalize(data, 'counties', ['state', 'shortname', ['info', 'governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich

# %% [markdown]
# # YAML parsing
# - YAML (short for "YAML Ain't Markup Language") is a human-readable data serialization format that is commonly used for configuration files, data exchange, and other structured data.
# - pyyaml: Python library that enables parsing and serialization of data in YAML format (parsing and conversion)

# %%
# %%writefile config.yaml
# # sample YAML configuration file (generateed by ChatGPT)
#
# server:
#   host: localhost
#   port: 8080
#
# database:
#   host: localhost
#   port: 5432
#   user: myuser
#   password: mypassword
# Out:
# Writing config.yaml

# %%
# !cat config.yaml
# Out:
# # sample YAML configuration file (generateed by ChatGPT)
#
# server:
#   host: localhost
#   port: 8080
#
# database:
#   host: localhost
#   port: 5432
#   user: myuser
#   password: mypassword

# %%
# !pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0)

# %%
import yaml

with open('config.yaml', 'r') as f:
    config = yaml.safe_load(f)
    # config = yaml.load(f)        # for more complex types
print(config, type(config))
print(config['server']['host'])    # Output: localhost
print(config['database']['user'])  # Output: myuser
# Out:
# {'server': {'host': 'localhost', 'port': 8080}, 'database': {'host': 'localhost', 'port': 5432, 'user': 'myuser', 'password': 'mypassword'}} <class 'dict'>
# localhost
# myuser

# %% [markdown]
# # HTML Parsing
# - before you do this example, try to see and run some example HTML files which are in this directory

# %%
from bs4 import BeautifulSoup

# %%
html_text = """
<html>
<body>
  <h1> reading web page with python </h1>
     <p> page analysis </p>
     <p> page alignment </p>
     <td>some text</td><td></td><td><p>more text</p></td><td>even <p>more text</p></td>
</body>
</html>
"""

# %%
soup = BeautifulSoup(html_text, 'html.parser')
soup
# Out:
# <html>
# <body>
# <h1> reading web page with python </h1>
# <p> page analysis </p>
# <p> page alignment </p>
# <td>some text</td><td></td><td><p>more text</p></td><td>even <p>more text</p></td>
# </body>
# </html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.h1
# Out:
# <h1> reading web page with python </h1>

# %%
soup.h1.text.strip()
# Out:
# 'reading web page with python'

# %%
soup.p
# Out:
# <p> page analysis </p>

# %%
soup.p.next_sibling.next_sibling
# Out:
# <p> page alignment </p>

# %%
soup.td.next_sibling.next_sibling
# Out:
# <td><p>more text</p></td>

# %%
print(soup.td.next_sibling, soup.td.next_sibling.text)
# Out:
# <td></td>

# %%
html_text2 = """
<html>
<body>
  <h1 id="title"> reading web page with python </h1>
     <p id="body"> page analysis </p>
     <p> page alignment </p>
     <td>some text</td><td></td><td><p>more text</p></td><td>even <p>more text</p></td>
     <ul>
         <li><a href = "http://www.naver.com"> naver</a></li>
         <li><a href = "http://www.daum.net"> daum</a></li>
     </ul>
  <div id="xxx">
    <h1> Wiki-books store </h1>
    <ul class="item all">
      <li> introduction to game design </li>
      <li> introduction to python </li>
      <li> introduction to web design </li>
    </ul>
  </div>
</body>
</html>
"""

# %%
soup = BeautifulSoup(html_text2, 'html.parser')

# %%
soup
# Out:
# <html>
# <body>
# <h1 id="title"> reading web page with python </h1>
# <p id="body"> page analysis </p>
# <p> page alignment </p>
# <td>some text</td><td></td><td><p>more text</p></td><td>even <p>more text</p></td>
# <ul>
# <li><a href="http://www.naver.com"> naver</a></li>
# <li><a href="http://www.daum.net"> daum</a></li>
# </ul>
# <div id="xxx">
# <h1> Wiki-books store </h1>
# <ul class="item all">
# <li> introduction to game design </li>
# <li> introduction to python </li>
# <li> introduction to web design </li>
# </ul>
# </div>
# </body>
# </html>

# %% [markdown]
# ## access by tags

# %%
soup.find(id='title')
# Out:
# <h1 id="title"> reading web page with python </h1>

# %%
soup.find(id='body').text
# Out:
# ' page analysis '

# %%
soup.find_all('p')
# Out:
# [<p id="body"> page analysis </p>,
#  <p> page alignment </p>,
#  <p>more text</p>,
#  <p>more text</p>]

# %%
soup.find_all('li')
# Out:
# [<li><a href="http://www.naver.com"> naver</a></li>,
#  <li><a href="http://www.daum.net"> daum</a></li>,
#  <li> introduction to game design </li>,
#  <li> introduction to python </li>,
#  <li> introduction to web design </li>]

# %%
soup.find_all('li')[0]
# Out:
# <li><a href="http://www.naver.com"> naver</a></li>

# %%
soup.find_all('li')[0].text, soup.find_all('li')[0].attrs
# Out:
# (' naver', {})

# %%
soup.find_all('a')[0]
# Out:
# <a href="http://www.naver.com"> naver</a>

# %%
soup.find_all('a')[0].text, soup.find_all('a')[0].attrs
# Out:
# (' naver', {'href': 'http://www.naver.com'})

# %%
for aa in soup.find_all('a'):
    href = aa.attrs['href']
    text = aa.string
    print (text, "-->", href)
# Out:
#  naver --> http://www.naver.com
#  daum --> http://www.daum.net

# %% [markdown]
# ## access by regular expression

# %%
soup
# Out:
# <html>
# <body>
# <h1 id="title"> reading web page with python </h1>
# <p id="body"> page analysis </p>
# <p> page alignment </p>
# <td>some text</td><td></td><td><p>more text</p></td><td>even <p>more text</p></td>
# <ul>
# <li><a href="http://www.naver.com"> naver</a></li>
# <li><a href="http://www.daum.net"> daum</a></li>
# </ul>
# <div id="xxx">
# <h1> Wiki-books store </h1>
# <ul class="item all">
# <li> introduction to game design </li>
# <li> introduction to python </li>
# <li> introduction to web design </li>
# </ul>
# </div>
# </body>
# </html>

# %%
import re
soup.find_all(re.compile("^p"))   # tags starting with a character 'p'
# Out:
# [<p id="body"> page analysis </p>,
#  <p> page alignment </p>,
#  <p>more text</p>,
#  <p>more text</p>]

# %%
soup.find_all(re.compile("div" ))
# Out:
# [<div id="xxx">
#  <h1> Wiki-books store </h1>
#  <ul class="item all">
#  <li> introduction to game design </li>
#  <li> introduction to python </li>
#  <li> introduction to web design </li>
#  </ul>
#  </div>]

# %%
soup.find_all(href=re.compile("^http://"))
# Out:
# [<a href="http://www.naver.com"> naver</a>,
#  <a href="http://www.daum.net"> daum</a>]

# %% [markdown]
# ## access by css (Cascading Style Sheets) selector

# %%
soup.select('h1')    # by tags
# Out:
# [<h1 id="title"> reading web page with python </h1>,
#  <h1> Wiki-books store </h1>]

# %%
soup.select('#xxx')  # by id
# Out:
# [<div id="xxx">
#  <h1> Wiki-books store </h1>
#  <ul class="item all">
#  <li> introduction to game design </li>
#  <li> introduction to python </li>
#  <li> introduction to web design </li>
#  </ul>
#  </div>]

# %%
soup.select('.item') # by class name
# Out:
# [<ul class="item all">
#  <li> introduction to game design </li>
#  <li> introduction to python </li>
#  <li> introduction to web design </li>
#  </ul>]

# %%
soup.select('div .item')  # multi-components(tag=div, class=item)
# Out:
# [<ul class="item all">
#  <li> introduction to game design </li>
#  <li> introduction to python </li>
#  <li> introduction to web design </li>
#  </ul>]

# %%
soup.select("#xxx > ul > li")  # hierarchy (child)
# Out:
# [<li> introduction to game design </li>,
#  <li> introduction to python </li>,
#  <li> introduction to web design </li>]

# %%
soup.select_one("#xxx > ul > li")  # hierarchy (child)
# Out:
# <li> introduction to game design </li>

# %%
soup.select("div li")   # hierarchy (div tag >>> ul tag) (descendants)
# Out:
# [<li> introduction to game design </li>,
#  <li> introduction to python </li>,
#  <li> introduction to web design </li>]

# %% [markdown]
# - find with classes

# %%
text = '<p class="body strikeout"></p>'

css_soup = BeautifulSoup(text, 'html.parser')
css_soup.find_all("p", class_="strikeout")  # can have multiple values for a class
# Out:
# [<p class="body strikeout"></p>]

# %%
css_soup.find_all("p", class_="body")
# Out:
# [<p class="body strikeout"></p>]

# %%
# If you want to search for tags that match two or more CSS classes,
# you should use a CSS selector:
css_soup.select("p.body.strikeout")
# Out:
# [<p class="body strikeout"></p>]

# %%
css_soup.select("p.strikeout")
# Out:
# [<p class="body strikeout"></p>]

# %% [markdown]
# # Example from JOBKOREA
# - confirmed in 2023.7.13
# - kr.indeed.com (search for 'data science', 'seoul')
# - Remember that web pages are changing.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# search for 'data scientist', 'seoul' in JobaKorea
url = 'https://www.jobkorea.co.kr/Search/?stext=data%20scientist&local=I000'
link = requests.get(url)
soup = BeautifulSoup(link.text, 'html.parser')

# %%
link.status_code
# Out:
# 200

# %%
soup.select('.recruit-info')
# Out:
# [<div class="recruit-info" style="">
#  <div class="list-filter-wrap">
#  <p class="filter-text">총 <strong class="dev_tot">59</strong>건</p>
#  <div class="btn-wrap">
#  <button class="btn-list-filter pseudo-icn lazyBg blk-arw" type="button">정확도순</button>
#  <div class="layer-comn layer-filter">
#  <ul class="dev_list_filter" data-key="Ord">
#  <li><button class="filter" data-val="ExactDesc" type="button">정확도순</button></li>
#  <li><button class="filter" data-val="RegDtDesc" type="button">등록일순</button></li>
#  <li><button class="filter" data-val="EditDtDesc" type="button">최신업데이트순</button></li>
#  <li><button class="filter" data-val="ApplyCloseDtAsc" type="button">마감임박순</button></li>
#  <li><button class="filter" data-val="ReadCntDesc" type="button">조회수순</button></li>
#  <li><button class="filter" data-val="ApplicantDesc" type="button">지원자순</button></li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="lists">
#  ﻿
#
#
#  <div class="lists-cnt dev_list" total-count="59">
#  <div class="list-default">
#  <ul class="clear">
#  <li class="list-post" data-gainfo='{"dimension42":"42399389", "dimension43":"제약·보건·바이오", "dimension44":"데이터엔지니어,데이터사이언티스트", "dimension45":"[서울본사] Data Scientist 신입/경력 채용", "dimension46":"서울", "dimension65":"N", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"24630972", "dimension48":"드림씨아이에스"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42399389?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=1" data-gino="44955215" data-gno="42399389" data-listno="1" data-mem-sys="24630972" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42399389?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=1" nav-src="/Search/_ContentsGIRead?Gno=42399389&amp;Mem_Type_Code=C&amp;Mem_Sys_No=24630972" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42399389]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42399389]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="드림씨아이에스">드림씨아이에스</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-24630972" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42399389?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=1" nav-src="/Search/_ContentsGIRead?Gno=42399389&amp;Mem_Type_Code=C&amp;Mem_Sys_No=24630972" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42399389]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42399389]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[서울본사] Data Scientist 신입/경력 채용">
#                                      [서울본사] <strong>Data Scientist</strong> 신입/경력 채용
#                                  </a>
#  <p class="option">
#  <span class="exp">신입·경력</span>
#  <span class="edu">석사↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 종로구</span>
#  <span class="date">~07/23(일)</span>
#  </p>
#  <p class="etc">빅데이터, 데이터분석</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44955215" data-brazeinfo="[서울본사] Data Scientist 신입/경력 채용|42399389|44955215|yyyy-MM-dd|yyyy-MM-dd|드림씨아이에스|24630972" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/List_GI/GIB_Read_homepage_Link.asp?GI_NO=44955215" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42390372", "dimension43":"전기·전자·제어", "dimension44":"DBA,데이터엔지니어,머신러닝엔지니어,클라우드엔지니어", "dimension45":"[HE본부] 마케팅 자동화 전문가(Data Scientist) 경력채용", "dimension46":"서울", "dimension65":"N", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"21247745", "dimension48":"엘지전자㈜"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42390372?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=2" data-gino="44947016" data-gno="42390372" data-listno="2" data-mem-sys="21247745" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42390372?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=2" nav-src="/Search/_ContentsGIRead?Gno=42390372&amp;Mem_Type_Code=C&amp;Mem_Sys_No=21247745" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42390372]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42390372]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="엘지전자㈜">엘지전자㈜</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-21247745" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42390372?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=2" nav-src="/Search/_ContentsGIRead?Gno=42390372&amp;Mem_Type_Code=C&amp;Mem_Sys_No=21247745" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42390372]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42390372]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[HE본부] 마케팅 자동화 전문가(Data Scientist) 경력채용">
#                                      [HE본부] 마케팅 자동화 전문가(<strong>Data Scientist</strong>) 경력채용
#                                  </a>
#  <p class="option">
#  <span class="exp">경력</span>
#  <span class="edu">대졸↑</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 영등포구</span>
#  <span class="date">~07/28(금)</span>
#  </p>
#  <p class="etc">빅데이터, 인공지능, 데이터마이닝, 클라우드아키텍트</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44947016" data-brazeinfo="[HE본부] 마케팅 자동화 전문가(Data Scientist) 경력채용|42390372|44947016|yyyy-MM-dd|yyyy-MM-dd|엘지전자㈜|21247745" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/List_GI/GIB_Read_homepage_Link.asp?GI_NO=44947016" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42310587", "dimension43":"전기·전자·제어", "dimension44":"데이터엔지니어,데이터사이언티스트", "dimension45":"[한국영업본부] Data Scientist 경력채용", "dimension46":"서울", "dimension65":"N", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"21247745", "dimension48":"엘지전자㈜"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42310587?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=3" data-gino="44876487" data-gno="42310587" data-listno="3" data-mem-sys="21247745" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42310587?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=3" nav-src="/Search/_ContentsGIRead?Gno=42310587&amp;Mem_Type_Code=C&amp;Mem_Sys_No=21247745" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42310587]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42310587]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="엘지전자㈜">엘지전자㈜</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-21247745" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42310587?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=3" nav-src="/Search/_ContentsGIRead?Gno=42310587&amp;Mem_Type_Code=C&amp;Mem_Sys_No=21247745" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42310587]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42310587]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[한국영업본부] Data Scientist 경력채용">
#                                      [한국영업본부] <strong>Data Scientist</strong> 경력채용
#                                  </a>
#  <p class="option">
#  <span class="exp">경력</span>
#  <span class="edu">대졸↑</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 중구</span>
#  <span class="date">~07/31(월)</span>
#  </p>
#  <p class="etc">데이터분석, 데이터파이프라인</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44876487" data-brazeinfo="[한국영업본부] Data Scientist 경력채용|42310587|44876487|yyyy-MM-dd|yyyy-MM-dd|엘지전자㈜|21247745" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/List_GI/GIB_Read_homepage_Link.asp?GI_NO=44876487" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42310561", "dimension43":"전기·전자·제어", "dimension44":"데이터엔지니어,데이터사이언티스트", "dimension45":"[한국영업본부] Data Scientist/Data Engineer 경력채용", "dimension46":"서울", "dimension65":"N", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"21247745", "dimension48":"엘지전자㈜"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42310561?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=4" data-gino="44876463" data-gno="42310561" data-listno="4" data-mem-sys="21247745" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42310561?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=4" nav-src="/Search/_ContentsGIRead?Gno=42310561&amp;Mem_Type_Code=C&amp;Mem_Sys_No=21247745" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42310561]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42310561]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="엘지전자㈜">엘지전자㈜</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-21247745" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42310561?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=4" nav-src="/Search/_ContentsGIRead?Gno=42310561&amp;Mem_Type_Code=C&amp;Mem_Sys_No=21247745" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42310561]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42310561]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[한국영업본부] Data Scientist/Data Engineer 경력채용">
#                                      [한국영업본부] <strong>Data Scientist</strong>/Data Engineer 경력채용
#                                  </a>
#  <p class="option">
#  <span class="exp">경력</span>
#  <span class="edu">대졸↑</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 중구</span>
#  <span class="date">~07/31(월)</span>
#  </p>
#  <p class="etc">데이터분석, 데이터파이프라인</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44876463" data-brazeinfo="[한국영업본부] Data Scientist/Data Engineer 경력채용|42310561|44876463|yyyy-MM-dd|yyyy-MM-dd|엘지전자㈜|21247745" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/List_GI/GIB_Read_homepage_Link.asp?GI_NO=44876463" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42238652", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"앱개발자,네트워크엔지니어,데이터엔지니어,데이터사이언티스트,머신러닝엔지니어,웹퍼블리셔,IT·기술영업", "dimension45":"각 부문별 경력사원 수시채용(Data Scientist)", "dimension46":"서울", "dimension65":"N", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"37371128", "dimension48":"케이티넥스알"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42238652?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=5" data-gino="44812656" data-gno="42238652" data-listno="5" data-mem-sys="37371128" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42238652?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=5" nav-src="/Search/_ContentsGIRead?Gno=42238652&amp;Mem_Type_Code=C&amp;Mem_Sys_No=37371128" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42238652]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42238652]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="케이티넥스알">케이티넥스알</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-37371128" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42238652?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=5" nav-src="/Search/_ContentsGIRead?Gno=42238652&amp;Mem_Type_Code=C&amp;Mem_Sys_No=37371128" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42238652]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42238652]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="각 부문별 경력사원 수시채용(Data Scientist)">
#                                      각 부문별 경력사원 수시채용(<strong>Data Scientist</strong>)
#                                  </a>
#  <p class="option">
#  <span class="exp">경력</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 송파구</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">빅데이터, 솔루션영업, 네트워크관리, data science, 데이터분석, yarn, kubernetes, RDBMS, Cloud</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44812656" data-brazeinfo="각 부문별 경력사원 수시채용(Data Scientist)|42238652|44812656|yyyy-MM-dd|yyyy-MM-dd|케이티넥스알|37371128" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/List_GI/GIB_Read_homepage_Link.asp?GI_NO=44812656" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42285349", "dimension43":"모바일·APP", "dimension44":"DBA,데이터엔지니어,데이터사이언티스트", "dimension45":"[직방] Senior Data Scientist", "dimension46":"서울, 경기, 인천", "dimension65":"N", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"32422544", "dimension48":"㈜직방"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42285349?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=6" data-gino="44853823" data-gno="42285349" data-listno="6" data-mem-sys="32422544" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42285349?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=6" nav-src="/Search/_ContentsGIRead?Gno=42285349&amp;Mem_Type_Code=C&amp;Mem_Sys_No=32422544" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42285349]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42285349]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜직방">㈜직방</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-32422544" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42285349?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=6" nav-src="/Search/_ContentsGIRead?Gno=42285349&amp;Mem_Type_Code=C&amp;Mem_Sys_No=32422544" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42285349]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42285349]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[직방] Senior Data Scientist">
#                                      [직방] Senior <strong>Data Scientist</strong>
#  </a>
#  <p class="option">
#  <span class="exp">경력5년↑</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울 외</span>
#  <span class="loc long">서울 강남구 외</span>
#  <span class="date">~08/03(목)</span>
#  </p>
#  <p class="etc">데이터시각화, BI, 모바일App, 데이터분석, 분석모델링</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44853823" data-brazeinfo="[직방] Senior Data Scientist|42285349|44853823|yyyy-MM-dd|yyyy-MM-dd|㈜직방|32422544" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/List_GI/GIB_Read_homepage_Link.asp?GI_NO=44853823" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42394645", "dimension43":"IT컨설팅", "dimension44":"데이터엔지니어,데이터사이언티스트,머신러닝엔지니어", "dimension45":"Data Scientist 신입/경력자 채용", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"17009338", "dimension48":"비에이코리아㈜"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42394645?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=7" data-gino="44950940" data-gno="42394645" data-listno="7" data-mem-sys="17009338" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42394645?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=7" nav-src="/Search/_ContentsGIRead?Gno=42394645&amp;Mem_Type_Code=C&amp;Mem_Sys_No=17009338" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42394645]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42394645]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="비에이코리아㈜">비에이코리아㈜</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-17009338" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42394645?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=7" nav-src="/Search/_ContentsGIRead?Gno=42394645&amp;Mem_Type_Code=C&amp;Mem_Sys_No=17009338" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42394645]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42394645]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="Data Scientist 신입/경력자 채용">
#  <strong>Data Scientist</strong> 신입/경력자 채용
#                                  </a>
#  <p class="option">
#  <span class="exp">신입·경력</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직 외</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 영등포구</span>
#  <span class="date">~08/31(목)</span>
#  </p>
#  <p class="etc">빅데이터, 딥러닝, 인공지능, 데이터분석</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44950940" data-brazeinfo="Data Scientist 신입/경력자 채용|42394645|44950940|yyyy-MM-dd|yyyy-MM-dd|비에이코리아㈜|17009338" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42351457", "dimension43":"쇼핑몰·오픈마켓·소셜커머스", "dimension44":"데이터사이언티스트", "dimension45":"AI Data Scientist 채용 (경력)", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"37213358", "dimension48":"㈜쇼퍼하우스"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42351457?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=8" data-gino="44912863" data-gno="42351457" data-listno="8" data-mem-sys="37213358" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42351457?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=8" nav-src="/Search/_ContentsGIRead?Gno=42351457&amp;Mem_Type_Code=C&amp;Mem_Sys_No=37213358" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42351457]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42351457]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜쇼퍼하우스">㈜쇼퍼하우스</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-37213358" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42351457?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=8" nav-src="/Search/_ContentsGIRead?Gno=42351457&amp;Mem_Type_Code=C&amp;Mem_Sys_No=37213358" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42351457]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42351457]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="AI Data Scientist 채용 (경력)">
#                                      AI <strong>Data Scientist</strong> 채용 (경력)
#                                  </a>
#  <p class="option">
#  <span class="exp">경력3년↑</span>
#  <span class="edu">석사↑</span>
#  <span>정규직 외</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 강남구</span>
#  <span class="date">~09/10(일)</span>
#  </p>
#  <p class="etc">B2B, 상품기획, B2C, 데이터시각화, 데이터분석, 분석모델링, 오픈마켓, 소셜커머스</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44912863" data-brazeinfo="AI Data Scientist 채용 (경력)|42351457|44912863|yyyy-MM-dd|yyyy-MM-dd|㈜쇼퍼하우스|37213358" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42339002", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"웹개발자,앱개발자,머신러닝엔지니어", "dimension45":"AI R&amp;D / 3D 비전 / 개발 / 보안 / Data Scientist 병역 특례 전문연구요원 모집", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"33183712", "dimension48":"㈜델타엑스"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42339002?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=9" data-gino="44901610" data-gno="42339002" data-listno="9" data-mem-sys="33183712" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42339002?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=9" nav-src="/Search/_ContentsGIRead?Gno=42339002&amp;Mem_Type_Code=C&amp;Mem_Sys_No=33183712" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42339002]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42339002]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜델타엑스">㈜델타엑스</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-33183712" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42339002?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=9" nav-src="/Search/_ContentsGIRead?Gno=42339002&amp;Mem_Type_Code=C&amp;Mem_Sys_No=33183712" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42339002]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42339002]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="AI R&amp;D / 3D 비전 / 개발 / 보안 / Data Scientist 병역 특례 전문연구요원 모집">
#                                      AI R&amp;D / 3D 비전 / 개발 / 보안 / <strong>Data Scientist</strong> 병역 특례 전문연구요원 모집
#                                  </a>
#  <p class="option">
#  <span class="exp">신입·경력</span>
#  <span class="edu">석사↑</span>
#  <span>정규직 외</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 중구</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">모바일앱개발, 소프트웨어개발, 솔루션, BigData, 딥러닝</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44901610" data-brazeinfo="AI R&amp;D / 3D 비전 / 개발 / 보안 / Data Scientist 병역 특례 전문연구요원 모집|42339002|44901610|yyyy-MM-dd|yyyy-MM-dd|㈜델타엑스|33183712" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42325085", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"데이터엔지니어,데이터사이언티스트,머신러닝엔지니어", "dimension45":"데이터 분석 (Data Scientist) 채용", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"32056944", "dimension48":"㈜에이브랩스"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42325085?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=10" data-gino="44889014" data-gno="42325085" data-listno="10" data-mem-sys="32056944" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42325085?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=10" nav-src="/Search/_ContentsGIRead?Gno=42325085&amp;Mem_Type_Code=C&amp;Mem_Sys_No=32056944" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42325085]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42325085]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜에이브랩스">㈜에이브랩스</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-32056944" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42325085?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=10" nav-src="/Search/_ContentsGIRead?Gno=42325085&amp;Mem_Type_Code=C&amp;Mem_Sys_No=32056944" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42325085]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42325085]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="데이터 분석 (Data Scientist) 채용">
#                                      데이터 분석 (<strong>Data Scientist</strong>) 채용
#                                  </a>
#  <p class="option">
#  <span class="exp">신입·경력</span>
#  <span class="edu">학력무관</span>
#  <span>정규직 외</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 중구</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">BigData, 빅데이터, 데이터분석, 딥러닝, 인공지능</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44889014" data-brazeinfo="데이터 분석 (Data Scientist) 채용|42325085|44889014|yyyy-MM-dd|yyyy-MM-dd|㈜에이브랩스|32056944" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42290495", "dimension43":"포털·컨텐츠·커뮤니티", "dimension44":"데이터사이언티스트", "dimension45":"Data Scientist", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"36694653", "dimension48":"링거스튜디오"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42290495?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=11" data-gino="44858600" data-gno="42290495" data-listno="11" data-mem-sys="36694653" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42290495?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=11" nav-src="/Search/_ContentsGIRead?Gno=42290495&amp;Mem_Type_Code=C&amp;Mem_Sys_No=36694653" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42290495]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42290495]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="링거스튜디오">링거스튜디오</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-36694653" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42290495?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=11" nav-src="/Search/_ContentsGIRead?Gno=42290495&amp;Mem_Type_Code=C&amp;Mem_Sys_No=36694653" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42290495]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42290495]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="Data Scientist">
#  <strong>Data Scientist</strong>
#  </a>
#  <p class="option">
#  <span class="exp">경력3년↑</span>
#  <span class="edu">학력무관</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 종로구</span>
#  <span class="date">~09/02(토)</span>
#  </p>
#  <p class="etc">데이터시각화, BI, 데이터분석, 분석모델링</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44858600" data-brazeinfo="Data Scientist|42290495|44858600|yyyy-MM-dd|yyyy-MM-dd|링거스튜디오|36694653" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42221269", "dimension43":"제약·보건·바이오", "dimension44":"데이터사이언티스트", "dimension45":"Data Scientist 채용", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"32481189", "dimension48":"바이온사이트"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42221269?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=12" data-gino="44797220" data-gno="42221269" data-listno="12" data-mem-sys="32481189" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42221269?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=12" nav-src="/Search/_ContentsGIRead?Gno=42221269&amp;Mem_Type_Code=C&amp;Mem_Sys_No=32481189" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42221269]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42221269]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="바이온사이트">바이온사이트</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-32481189" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42221269?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=12" nav-src="/Search/_ContentsGIRead?Gno=42221269&amp;Mem_Type_Code=C&amp;Mem_Sys_No=32481189" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42221269]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42221269]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="Data Scientist 채용">
#  <strong>Data Scientist</strong> 채용
#                                  </a>
#  <p class="option">
#  <span class="exp">경력</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 강남구</span>
#  <span class="date">~08/25(금)</span>
#  </p>
#  <p class="etc">바이오, 데이터시각화, 의약, 데이터분석, 분석모델링</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44797220" data-brazeinfo="Data Scientist 채용|42221269|44797220|yyyy-MM-dd|yyyy-MM-dd|바이온사이트|32481189" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42157543", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"DBA,데이터사이언티스트", "dimension45":"데이터 사이언티스트 (Data Scientist) 경력직 채용", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"36179196", "dimension48":"㈜프라이데이즈랩"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42157543?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=13" data-gino="44740580" data-gno="42157543" data-listno="13" data-mem-sys="36179196" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42157543?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=13" nav-src="/Search/_ContentsGIRead?Gno=42157543&amp;Mem_Type_Code=C&amp;Mem_Sys_No=36179196" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42157543]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42157543]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜프라이데이즈랩">㈜프라이데이즈랩</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-36179196" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42157543?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=13" nav-src="/Search/_ContentsGIRead?Gno=42157543&amp;Mem_Type_Code=C&amp;Mem_Sys_No=36179196" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42157543]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42157543]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="데이터 사이언티스트 (Data Scientist) 경력직 채용">
#                                      데이터 사이언티스트 (<strong>Data Scientist</strong>) 경력직 채용
#                                  </a>
#  <p class="option">
#  <span class="exp">경력3년↑</span>
#  <span class="edu">학력무관</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 강남구 외</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">소프트웨어개발, BI, 데이터마이닝, 데이터관리, BI, 데이터분석, 데이터시각화, 분석모델링</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44740580" data-brazeinfo="데이터 사이언티스트 (Data Scientist) 경력직 채용|42157543|44740580|yyyy-MM-dd|yyyy-MM-dd|㈜프라이데이즈랩|36179196" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"41862506", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"머신러닝엔지니어", "dimension45":"[나스닥 상장 추진] 한류뱅크(주) AI Data Scientist 경력직 채용", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"39871527", "dimension48":"한류뱅크㈜"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/41862506?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=14" data-gino="44480194" data-gno="41862506" data-listno="14" data-mem-sys="39871527" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/41862506?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=14" nav-src="/Search/_ContentsGIRead?Gno=41862506&amp;Mem_Type_Code=C&amp;Mem_Sys_No=39871527" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=41862506]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=41862506]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="한류뱅크㈜">한류뱅크㈜</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-39871527" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/41862506?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=14" nav-src="/Search/_ContentsGIRead?Gno=41862506&amp;Mem_Type_Code=C&amp;Mem_Sys_No=39871527" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=41862506]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=41862506]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[나스닥 상장 추진] 한류뱅크(주) AI Data Scientist 경력직 채용">
#                                      [나스닥 상장 추진] 한류뱅크(주) AI <strong>Data Scientist</strong> 경력직 채용
#                                  </a>
#  <p class="option">
#  <span class="exp">경력3년↑</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 영등포구</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">모바일앱개발, 소프트웨어개발, 모델링, 딥러닝, 자연어처리(NLP), 인공지능, 챗봇</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44480194" data-brazeinfo="[나스닥 상장 추진] 한류뱅크(주) AI Data Scientist 경력직 채용|41862506|44480194|yyyy-MM-dd|yyyy-MM-dd|한류뱅크㈜|39871527" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"41849853", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"데이터사이언티스트,머신러닝엔지니어,R&amp;D·연구원", "dimension45":"[AI 연구소] 3D Data Scientist 채용(주임 또는 연구원급): 영상 및 PCD 등", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"16020", "dimension48":"㈜인피닉"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/41849853?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=15" data-gino="44468897" data-gno="41849853" data-listno="15" data-mem-sys="16020" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/41849853?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=15" nav-src="/Search/_ContentsGIRead?Gno=41849853&amp;Mem_Type_Code=C&amp;Mem_Sys_No=16020" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=41849853]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=41849853]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜인피닉">㈜인피닉</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-16020" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/41849853?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=15" nav-src="/Search/_ContentsGIRead?Gno=41849853&amp;Mem_Type_Code=C&amp;Mem_Sys_No=16020" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=41849853]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=41849853]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[AI 연구소] 3D Data Scientist 채용(주임 또는 연구원급): 영상 및 PCD 등">
#                                      [AI 연구소] 3D <strong>Data Scientist</strong> 채용(주임 또는 연구원급): 영상 및 PCD 등
#                                  </a>
#  <p class="option">
#  <span class="exp">신입·경력</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직 외</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 강남구</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">소프트웨어개발, 솔루션, BigData, DataMining, 데이터분석, 데이터시각화, 분석모델링, 모델링, 딥러닝, 이미지프로세싱, 인공지능, 자동차, R&amp;D, 로봇설계, 연구·실험·기술, 조선·항공·우주</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44468897" data-brazeinfo="[AI 연구소] 3D Data Scientist 채용(주임 또는 연구원급): 영상 및 PCD 등|41849853|44468897|yyyy-MM-dd|yyyy-MM-dd|㈜인피닉|16020" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42361403", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"데이터엔지니어,데이터사이언티스트", "dimension45":"Data Scientist 경력 채용", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"37388944", "dimension48":"㈜브이피피랩"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42361403?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=16" data-gino="44921758" data-gno="42361403" data-listno="16" data-mem-sys="37388944" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42361403?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=16" nav-src="/Search/_ContentsGIRead?Gno=42361403&amp;Mem_Type_Code=C&amp;Mem_Sys_No=37388944" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42361403]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42361403]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜브이피피랩">㈜브이피피랩</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-37388944" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42361403?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=16" nav-src="/Search/_ContentsGIRead?Gno=42361403&amp;Mem_Type_Code=C&amp;Mem_Sys_No=37388944" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42361403]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42361403]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="Data Scientist 경력 채용">
#  <strong>Data Scientist</strong> 경력 채용
#                                  </a>
#  <p class="option">
#  <span class="exp">경력</span>
#  <span class="edu">초대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 마포구</span>
#  <span class="date">~09/11(월)</span>
#  </p>
#  <p class="etc">BigData, 빅데이터, 데이터레이크, 솔루션, 데이터시각화, ETL, SI, 데이터분석, 분석모델링, 소프트웨어개발, 데이터파이프라인, WAS</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44921758" data-brazeinfo="Data Scientist 경력 채용|42361403|44921758|yyyy-MM-dd|yyyy-MM-dd|㈜브이피피랩|37388944" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42254002", "dimension43":"솔루션·SI·CRM·ERP", "dimension44":"DBA,데이터엔지니어,데이터사이언티스트", "dimension45":"[경력] Data Scientist(데이터사이언티스트) 채용", "dimension46":"서울", "dimension65":"Y", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"59440", "dimension48":"㈜카비"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42254002?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=17" data-gino="44826325" data-gno="42254002" data-listno="17" data-mem-sys="59440" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42254002?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=17" nav-src="/Search/_ContentsGIRead?Gno=42254002&amp;Mem_Type_Code=C&amp;Mem_Sys_No=59440" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42254002]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42254002]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="㈜카비">㈜카비</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-59440" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42254002?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=17" nav-src="/Search/_ContentsGIRead?Gno=42254002&amp;Mem_Type_Code=C&amp;Mem_Sys_No=59440" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42254002]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42254002]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[경력] Data Scientist(데이터사이언티스트) 채용">
#                                      [경력] <strong>Data Scientist</strong>(데이터사이언티스트) 채용
#                                  </a>
#  <p class="option">
#  <span class="exp">경력3년↑</span>
#  <span class="edu">석사↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 금천구</span>
#  <span class="date">상시채용</span>
#  </p>
#  <p class="etc">BigData, 빅데이터, 데이터관리, 데이터레이크, 솔루션, DBMS, 데이터시각화, BI, 모델링, 데이터분석, 분석모델링, 데이터마이닝, 알고리즘, DataMining, 소프트웨어개발, 데이터파이프라인, 데이터사이언스, 데이터사이언티스트, 통계분석</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44826325" data-brazeinfo="[경력] Data Scientist(데이터사이언티스트) 채용|42254002|44826325|yyyy-MM-dd|yyyy-MM-dd|㈜카비|59440" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42390189", "dimension43":"전기·전자·제어", "dimension44":"데이터엔지니어,데이터사이언티스트", "dimension45":"[플랫폼사업센터] Data 전문가 채용(Architect, Analyst/Scientist ,Engineer)", "dimension46":"서울", "dimension65":"N", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"21247745", "dimension48":"엘지전자㈜"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42390189?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=18" data-gino="44946836" data-gno="42390189" data-listno="18" data-mem-sys="21247745" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42390189?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=18" nav-src="/Search/_ContentsGIRead?Gno=42390189&amp;Mem_Type_Code=C&amp;Mem_Sys_No=21247745" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42390189]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42390189]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="엘지전자㈜">엘지전자㈜</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-21247745" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42390189?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=18" nav-src="/Search/_ContentsGIRead?Gno=42390189&amp;Mem_Type_Code=C&amp;Mem_Sys_No=21247745" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42390189]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42390189]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[플랫폼사업센터] Data 전문가 채용(Architect, Analyst/Scientist ,Engineer)">
#                                      [플랫폼사업센터] Data 전문가 채용(Architect, Analyst/Scientist ,Engineer)
#                                  </a>
#  <p class="option">
#  <span class="exp">경력</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 강서구</span>
#  <span class="date">~07/30(일)</span>
#  </p>
#  <p class="etc">빅데이터, 데이터분석</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44946836" data-brazeinfo="[플랫폼사업센터] Data 전문가 채용(Architect, Analyst/Scientist ,Engineer)|42390189|44946836|yyyy-MM-dd|yyyy-MM-dd|엘지전자㈜|21247745" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/List_GI/GIB_Read_homepage_Link.asp?GI_NO=44946836" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42331642", "dimension43":"전기·전자·제어", "dimension44":"데이터엔지니어,소프트웨어개발자,전기·전자엔지니어,설계엔지니어,설비엔지니어,하드웨어엔지니어", "dimension45":"[BS본부] 2023년 중반기 신입사원 채용", "dimension46":"서울, 경기", "dimension65":"N", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"21247745", "dimension48":"엘지전자㈜"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42331642?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=19" data-gino="44894825" data-gno="42331642" data-listno="19" data-mem-sys="21247745" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42331642?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=19" nav-src="/Search/_ContentsGIRead?Gno=42331642&amp;Mem_Type_Code=C&amp;Mem_Sys_No=21247745" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42331642]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42331642]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="엘지전자㈜">엘지전자㈜</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-21247745" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42331642?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=19" nav-src="/Search/_ContentsGIRead?Gno=42331642&amp;Mem_Type_Code=C&amp;Mem_Sys_No=21247745" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42331642]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42331642]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[BS본부] 2023년 중반기 신입사원 채용">
#                                      [BS본부] 2023년 중반기 신입사원 채용
#                                  </a>
#  <p class="option">
#  <span class="exp">신입</span>
#  <span class="edu">대졸↑</span>
#  <span>정규직</span>
#  <span class="loc short">서울 외</span>
#  <span class="loc long">서울 영등포구 외</span>
#  <span class="date">~07/23(일)</span>
#  </p>
#  <p class="etc">빅데이터, 기구개발, 회로설계, 데이터분석, 구조설계, 포장설계, 통신설비, 프로토콜, 3D설계, lcm, 키오스크, PLC, 데이터사이언티스트</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44894825" data-brazeinfo="[BS본부] 2023년 중반기 신입사원 채용|42331642|44894825|yyyy-MM-dd|yyyy-MM-dd|엘지전자㈜|21247745" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/List_GI/GIB_Read_homepage_Link.asp?GI_NO=44894825" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  <li class="list-post" data-gainfo='{"dimension42":"42415462", "dimension43":"네트워크·통신서비스", "dimension44":"네트워크엔지니어,데이터사이언티스트,머신러닝엔지니어", "dimension45":"[CDO] AI Scientist - 추천/예측/타겟팅 경력사원 채용", "dimension46":"서울", "dimension65":"N", "dimension66":"일반기업", "dimension70":"무료", "dimension47":"22848630", "dimension48":"엘지유플러스"}' data-gavirturl="https://www.jobkorea.co.kr/virtual/Recruit/GI_Read/42415462?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=20" data-gino="44969713" data-gno="42415462" data-listno="20" data-mem-sys="22848630" data-mem-type="C">
#  <div class="post">
#  <div class="post-list-corp">
#  <a class="name dev_view" href="/Recruit/GI_Read/42415462?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=20" nav-src="/Search/_ContentsGIRead?Gno=42415462&amp;Mem_Type_Code=C&amp;Mem_Sys_No=22848630" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42415462]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42415462]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="엘지유플러스">엘지유플러스</a>
#  <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-22848630" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
#  </div>
#  <div class="post-list-info">
#  <a class="title dev_view" href="/Recruit/GI_Read/42415462?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=20" nav-src="/Search/_ContentsGIRead?Gno=42415462&amp;Mem_Type_Code=C&amp;Mem_Sys_No=22848630" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42415462]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42415462]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="[CDO] AI Scientist - 추천/예측/타겟팅 경력사원 채용">
#                                      [CDO] AI Scientist - 추천/예측/타겟팅 경력사원 채용
#                                  </a>
#  <p class="option">
#  <span class="exp">경력</span>
#  <span class="edu">대졸↑</span>
#  <span class="loc short">서울</span>
#  <span class="loc long">서울 용산구</span>
#  <span class="date">~07/26(수)</span>
#  </p>
#  <p class="etc">인공지능, 네트워크관리, 데이터분석</p>
#  <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44969713" data-brazeinfo="[CDO] AI Scientist - 추천/예측/타겟팅 경력사원 채용|42415462|44969713|yyyy-MM-dd|yyyy-MM-dd|엘지유플러스|22848630" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
#  </div>
#  <div class="post-list-apply">
#  <button class="btn-post-homepage dev_new_pop" onclick="_LA.EVT('5283');GA_Event('통합검색_PC', '채용정보', '홈페이지 지원');" src="/List_GI/GIB_Read_homepage_Link.asp?GI_NO=44969713" type="button"><span>홈페이지 지원</span></button>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <?xml version="1.0" encoding="utf-16"?>
#  <div class="tplPagination newVer wide">
#  <ul>
#  <li>
#  <span class="now">1</span>
#  </li>
#  <li>
#  <a href="/Search/RecruitList?stext=data%20scientist&amp;local=I000&amp;Page_No=2" page-no="2">2</a>
#  </li>
#  <li>
#  <a href="/Search/RecruitList?stext=data%20scientist&amp;local=I000&amp;Page_No=3" page-no="3">3</a>
#  </li>
#  </ul>
#  <p>
#  <a class="tplBtn btnPgnNext" href="/Search/RecruitList?stext=data%20scientist&amp;local=I000&amp;Page_No=2" page-no="2">
#  				다음<i class="ico"> </i></a>
#  </p>
#  </div><?xml version="1.0" encoding="utf-16"?>
#  <div class="tplPagination newVer short clear">
#  <ul class="clear">
#  <li>
#  <span class="now">1</span>
#  </li>
#  <li>
#  <span class="pgTotal">3</span>
#  </li>
#  </ul>
#  <p>
#  <a class="tplBtn btnPgnNext" href="/Search/RecruitList?stext=data%20scientist&amp;local=I000&amp;Page_No=2" page-no="2">
#  <i class="ico"> </i>
#  </a>
#  </p>
#  </div> <p class="copyright">© <strong><a href="http://company.jobkorea.co.kr/" target="_blank">JOBKOREA</a></strong> LLC. All rights reserved.</p>
#  </div>
#  </div>
#  </div>]

# %%
len(soup.select('.recruit-info'))
# Out:
# 1

# %%
ss = soup.select('.recruit-info')[0].select('.lists')
len(ss)
# Out:
# 1

# %%
len(ss[0].select('.post'))
# Out:
# 20

# %%
ss[0].select('.post')[10]
# Out:
# <div class="post">
# <div class="post-list-corp">
# <a class="name dev_view" href="/Recruit/GI_Read/42290495?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=11" nav-src="/Search/_ContentsGIRead?Gno=42290495&amp;Mem_Type_Code=C&amp;Mem_Sys_No=36694653" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42290495]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42290495]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="링거스튜디오">링거스튜디오</a>
# <button class="btn-fav pseudo-icn-old lazyBg heart dev_favor-36694653" onclick="GA_Event('통합검색_PC', '채용정보','관심_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">관심기업</button>
# </div>
# <div class="post-list-info">
# <a class="title dev_view" href="/Recruit/GI_Read/42290495?Oem_Code=C1&amp;logpath=1&amp;stext=data scientist&amp;listno=11" nav-src="/Search/_ContentsGIRead?Gno=42290495&amp;Mem_Type_Code=C&amp;Mem_Sys_No=36694653" onclick="GA_Virtual_Dimension($(this).closest('.list-post[data-gno=42290495]').data('gainfo'));GA_Virtual('홈&gt;통합검색&gt;공고뷰', $(this).closest('.list-post[data-gno=42290495]').data('gavirturl'));GA_Event('통합검색_PC', '채용정보', '클릭');" title="Data Scientist">
# <strong>Data Scientist</strong>
# </a>
# <p class="option">
# <span class="exp">경력3년↑</span>
# <span class="edu">학력무관</span>
# <span>정규직</span>
# <span class="loc short">서울</span>
# <span class="loc long">서울 종로구</span>
# <span class="date">~09/02(토)</span>
# </p>
# <p class="etc">데이터시각화, BI, 데이터분석, 분석모델링</p>
# <button class="btn-scrap pseudo-icn-old lazyBg star dev_scrap-44858600" data-brazeinfo="Data Scientist|42290495|44858600|yyyy-MM-dd|yyyy-MM-dd|링거스튜디오|36694653" onclick="GA_Event('통합검색_PC', '채용정보','스크랩_' + ($(this).hasClass('on')?'해제':'등록'));" type="button">스크랩</button>
# </div>
# <div class="post-list-apply">
# <button class="btn-post-apply dev_direct_apply_list" onclick="GA_Event('통합검색_PC', '채용정보', '즉시지원');" type="button"><span>즉시지원</span></button>
# </div>
# </div>

# %%
ss[0].select('.post')[0].select('.post-list-info')[0].a.text.strip()
# Out:
# '[서울본사] Data Scientist 신입/경력 채용'

# %%
s0 = ss[0].select('.post')[0].select('.post-list-corp')
corp = s0[0].a.text
s0 = ss[0].select('.post')[0].select('.post-list-info')
title = s0[0].a.text.strip()
loc = s0[0].select('.loc.long')[0].text
date = s0[0].select('.date')[0].text
etc = s0[0].select('.etc')[0].text

# %%
corp, title, loc, date, etc
# Out:
# ('드림씨아이에스',
#  '[서울본사] Data Scientist 신입/경력 채용',
#  '서울 종로구',
#  '~07/23(일)',
#  '빅데이터, 데이터분석')

# %%
ss = soup.select('.recruit-info')[0].select('.lists')
post = ss[0].select('.post')
print("There are a total of {} job postings.".format(len(post)))

corps, titles, locs, dates, etcs = [], [], [], [], []
for i in range(len(post)):
    s0 = post[i].select('.post-list-corp')
    corps.append(s0[0].a.text)
    s0 = post[i].select('.post-list-info')
    titles.append(s0[0].a.text.strip())
    locs.append(s0[0].select('.loc.long')[0].text)
    dates.append(s0[0].select('.date')[0].text)
    etcs.append(s0[0].select('.etc')[0].text)
# Out:
# There are a total of 20 job postings.

# %%
pd.DataFrame(np.c_[corps, titles, locs, dates, etcs],
             columns=["corps", "titles", "locs", "dates", "etcs"])
# Out:
#        corps                                             titles       locs  \
# 0    드림씨아이에스                     [서울본사] Data Scientist 신입/경력 채용     서울 종로구
# 1      엘지전자㈜            [HE본부] 마케팅 자동화 전문가(Data Scientist) 경력채용    서울 영등포구
# 2      엘지전자㈜                       [한국영업본부] Data Scientist 경력채용      서울 중구
# 3      엘지전자㈜         [한국영업본부] Data Scientist/Data Engineer 경력채용      서울 중구
# 4     케이티넥스알                    각 부문별 경력사원 수시채용(Data Scientist)     서울 송파구
# 5        ㈜직방                         [직방] Senior Data Scientist   서울 강남구 외
# 6    비에이코리아㈜                           Data Scientist 신입/경력자 채용    서울 영등포구
# 7     ㈜쇼퍼하우스                          AI Data Scientist 채용 (경력)     서울 강남구
# 8      ㈜델타엑스  AI R&D / 3D 비전 / 개발 / 보안 / Data Scientist 병역 특...      서울 중구
# 9     ㈜에이브랩스                         데이터 분석 (Data Scientist) 채용      서울 중구
# 10    링거스튜디오                                     Data Scientist     서울 종로구
# 11    바이온사이트                                  Data Scientist 채용     서울 강남구
# 12  ㈜프라이데이즈랩                 데이터 사이언티스트 (Data Scientist) 경력직 채용   서울 강남구 외
# 13     한류뱅크㈜       [나스닥 상장 추진] 한류뱅크(주) AI Data Scientist 경력직 채용    서울 영등포구
# 14      ㈜인피닉  [AI 연구소] 3D Data Scientist 채용(주임 또는 연구원급): 영상 ...     서울 강남구
# 15    ㈜브이피피랩                               Data Scientist 경력 채용     서울 마포구
# 16       ㈜카비                  [경력] Data Scientist(데이터사이언티스트) 채용     서울 금천구
# 17     엘지전자㈜  [플랫폼사업센터] Data 전문가 채용(Architect, Analyst/Scien...     서울 강서구
# 18     엘지전자㈜                           [BS본부] 2023년 중반기 신입사원 채용  서울 영등포구 외
# 19    엘지유플러스             [CDO] AI Scientist - 추천/예측/타겟팅 경력사원 채용     서울 용산구
#
#         dates                                               etcs
# 0   ~07/23(일)                                        빅데이터, 데이터분석
# 1   ~07/28(금)                       빅데이터, 인공지능, 데이터마이닝, 클라우드아키텍트
# 2   ~07/31(월)                                    데이터분석, 데이터파이프라인
# 3   ~07/31(월)                                    데이터분석, 데이터파이프라인
# 4        상시채용  빅데이터, 솔루션영업, 네트워크관리, data science, 데이터분석, yarn...
# 5   ~08/03(목)                   데이터시각화, BI, 모바일App, 데이터분석, 분석모델링
# 6   ~08/31(목)                             빅데이터, 딥러닝, 인공지능, 데이터분석
# 7   ~09/10(일)  B2B, 상품기획, B2C, 데이터시각화, 데이터분석, 분석모델링, 오픈마켓, 소셜커머스
# 8        상시채용                 모바일앱개발, 소프트웨어개발, 솔루션, BigData, 딥러닝
# 9        상시채용                    BigData, 빅데이터, 데이터분석, 딥러닝, 인공지능
# 10  ~09/02(토)                           데이터시각화, BI, 데이터분석, 분석모델링
# 11  ~08/25(금)                      바이오, 데이터시각화, 의약, 데이터분석, 분석모델링
# 12       상시채용  소프트웨어개발, BI, 데이터마이닝, 데이터관리, BI, 데이터분석, 데이터시각화,...
# 13       상시채용    모바일앱개발, 소프트웨어개발, 모델링, 딥러닝, 자연어처리(NLP), 인공지능, 챗봇
# 14       상시채용  소프트웨어개발, 솔루션, BigData, DataMining, 데이터분석, 데이터시...
# 15  ~09/11(월)  BigData, 빅데이터, 데이터레이크, 솔루션, 데이터시각화, ETL, SI, 데...
# 16       상시채용  BigData, 빅데이터, 데이터관리, 데이터레이크, 솔루션, DBMS, 데이터시각...
# 17  ~07/30(일)                                        빅데이터, 데이터분석
# 18  ~07/23(일)  빅데이터, 기구개발, 회로설계, 데이터분석, 구조설계, 포장설계, 통신설비, 프로토...
# 19  ~07/26(수)                                인공지능, 네트워크관리, 데이터분석

# %% [markdown]
# # Exercise
# - .text: extract the combined text content of an element and its descendants. (recommended)
# - .string: extract the text content of an individual element without considering any nested elements.
# - It's important to note that the string attribute can only be used when an element has a single string as its content. If an element has multiple strings or tags, string will return None.
# - In summary, text returns the combined text content of an element and its descendants, while string returns the text content of an individual element without considering its children.

# %%
# .text and .string
html_text = """
<html>
<body>
  <td>some text</td>
  <td></td>
  <td><p>more text</p></td>
  <td>even <p>more text</p></td>"
</body>
</html>
"""
soup = BeautifulSoup(html_text, 'html.parser')

# %%
soup.find_all('td')
# Out:
# [<td>some text</td>,
#  <td></td>,
#  <td><p>more text</p></td>,
#  <td>even <p>more text</p></td>]

# %%
for i in soup.find_all('td'):
    print(i.string)
# Out:
# some text
# None
# more text
# None

# %%
for i in soup.find_all('td'):
    print(i.text)
# Out:
# some text
#
# more text
# even more text

# %% [markdown]
# ### Request
# - get
# - put

# %%
import requests

# the following two are the same.
parameters = {"lat": 40.71, "lon": -74}
response = requests.get("http://api.open-notify.org/iss-now.json",
                        params=parameters)
print(response.content)

response = requests.get("http://api.open-notify.org/iss-now.json?lat=40.71&lon=-74")
print(response.content)
# Out:
# b'{"timestamp": 1689835502, "message": "success", "iss_position": {"latitude": "28.6522", "longitude": "-80.1510"}}'
# b'{"timestamp": 1689835502, "message": "success", "iss_position": {"latitude": "28.6522", "longitude": "-80.1510"}}'

# %%
response.status_code
# Out:
# 200

# %%
response = requests.get("http://api.open-notify.org/iss-now.json")

# %%
response.content
# Out:
# b'{"timestamp": 1689835502, "message": "success", "iss_position": {"latitude": "28.6522", "longitude": "-80.1510"}}'

# %% [markdown]
# - getting JSON from a request

# %%
# Make the same request we did

response = requests.get("http://api.open-notify.org/iss-now.json")

# Get the response data as a Python object.  Verify that it's a dictionary.
json_data = response.json()
print(type(json_data))
print(json_data)
# Out:
# <class 'dict'>
# {'timestamp': 1689835502, 'message': 'success', 'iss_position': {'latitude': '28.6522', 'longitude': '-80.1510'}}

# %%
# Headers is a dictionary
print(response.headers)
content_type = response.headers['Content-Type']
content_type
# Out:
# {'Server': 'nginx/1.10.3', 'Date': 'Thu, 20 Jul 2023 06:45:02 GMT', 'Content-Type': 'application/json', 'Content-Length': '113', 'Connection': 'keep-alive', 'access-control-allow-origin': '*'}
# 'application/json'
